# %%
import numpy as np
from matplotlib import pyplot as plt
a = np.linspace(1,10,10)
print(np.sum(a))
# Out:
# 55.0

# %%
x = 10*np.random.rand(1000)
xc = 5
s = np.exp(-(x-5)**2)
hbar = 1e-10
l = np.exp(1j*s/hbar)

plt.scatter(x,np.mod(s/hbar,np.pi))
plt.show()
print(np.angle(np.sum(l)))
print(np.angle(np.exp(1j*1/hbar)))
# Out:
# 1.3943162336684143
# -0.5092310721657347

# %%
np.angle(np.exp(1j*1))
# Out:
# 1.0

# %%
np.mod(200,3)
# Out:
# 2

# %%
z = np.linspace(0,100,10000)
a = np.random.rand(10000)
plt.scatter(z,a)
print(a)
# Out:
# [0.14739913 0.72084323 0.00205607 ... 0.62129474 0.57897602 0.44337321]

# %%
from scipy import integrate
